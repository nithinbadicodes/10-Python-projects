# %% [markdown]
# <a href="https://colab.research.google.com/github/nithinbadicodes/10-Python-projects/blob/master/Climate_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Climate analysis

# %% [markdown]
# * Level: Medium You work for a cutting-edge environmental organization tracking climate change data. Your mission is to visualize temperature trends over time to see how the world’s climate has shifted. With tools like Matplotlib and Seaborn, you will create meaningful visualizations to share with researchers and scientists globally.
# * Task: Download the dataset from https://www.kaggle.com/datasets/phyamal/glasgow-weather-data-20152019
# * Use Matplotlib and Seaborn to create line charts and scatter plots to display temperature trends over time.
# * Key Concepts: Data visualization, Matplotlib, Seaborn.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('clean_weather_data.csv')
df['day'] = pd.to_datetime(df['day'], errors='coerce')
df = df.sort_values('day')
df.head()
# Out:
#          day  tempMin  tempMax                                  summary  \
# 0 2015-01-01     7.53    12.23       Possible light rain until evening.
# 1 2015-01-02     3.58     7.15  Possible light rain throughout the day.
# 2 2015-01-03    -0.61     6.54                Clear throughout the day.
# 3 2015-01-04    -0.63     7.59        Mostly cloudy throughout the day.
# 4 2015-01-05     6.51    10.43             Overcast throughout the day.
#
#                 desc  cloudCover  humidity  windSpeed  visibility
# 0               rain        0.80      0.89      14.69        4.43
# 1               rain        0.62      0.79      15.04        5.64
# 2               rain        0.31      0.84       4.48        6.20
# 3  partly-cloudy-day        0.78      0.85       4.35        6.22
# 4  partly-cloudy-day        0.85      0.91       6.20        5.91

# %%
plt.figure(figsize=(12,5))
plt.plot(df['day'], df['tempMin'], label='tempMin', alpha=0.7)
plt.plot(df['day'], df['tempMax'], label='tempMax', alpha=0.7)
plt.title('Daily Temperatures')
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.legend()
plt.show()

# %%
sns.pairplot(df[num_cols])
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(data=df, x='tempMax', y='humidity', alpha=0.7)
plt.title('tempMax vs humidity')
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(data=df, x='windSpeed', y='visibility', alpha=0.7)
plt.title('windSpeed vs visibility')
plt.show()

# %%
num_cols = ['tempMin','tempMax','cloudCover','humidity','windSpeed','visibility']
corr = df[num_cols].corr()


plt.figure(figsize=(7,5))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Based on this weather correlation heatmap, here are the key insights:
#
# • **Temperature variables are highly correlated** (0.8) - minimum and maximum temperatures move together as expected
#
# • **Cloud cover and humidity have a moderate positive relationship** (0.58) - more clouds typically accompany higher humidity
#
# • **Visibility decreases with humidity and cloud cover** (-0.43 and -0.26 respectively) - atmospheric moisture reduces visibility
#
# • **Maximum temperature and humidity are negatively correlated** (-0.36) - hotter days tend to be drier
#
# • **Wind speed shows weak relationships** with most other variables, suggesting it's largely independent of temperature and moisture conditions
#
# • **Cloud cover and maximum temperature are negatively related** (-0.11) - clearer skies associated with higher temperatures
#
# • **Most correlations are weak to moderate** (under 0.6), indicating weather variables have complex, non-linear relationships
